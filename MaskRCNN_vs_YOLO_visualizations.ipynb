# %%
#  BAR Chart
import matplotlib.pyplot as plt

# Data from the first table
iou_thresholds = ['0.50:0.95', '0.50', '0.75', '0.50:0.95', '0.50:0.95', '0.50:0.95']
areas = ['all', 'all', 'all', 'small', 'medium', 'large']
ap_values_model1 = [0.419, 0.498, 0.495, 0.000, 0.004, 0.419]
ar_values_model1 = [0.455, 0.445, 0.448, 0.000, 0.000, 0.460]

# Data from the second table
ap_values_model2 = [0.367, 0.522, 0.398, 0.179, 0.404, 0.521]
ar_values_model2 = [0.586, 0.315, 0.531, 0.366, 0.650, 0.767]

# Create subplots for AP and AR
fig, axes = plt.subplots(2, 1, figsize=(10, 12))

# Plot AP
axes[0].bar(range(len(ap_values_model1)), ap_values_model1, width=0.4, align='center', label='MaskRCNN', color='blue', alpha=0.6)
axes[0].bar([x + 0.4 for x in range(len(ap_values_model2))], ap_values_model2, width=0.4, align='center', label='YOLO v8', color='red', alpha=0.6)
axes[0].set_xticks(range(len(ap_values_model1)))
axes[0].set_xticklabels([f'IoU={iou}, Area={area}' for iou, area in zip(iou_thresholds, areas)], rotation=45)
axes[0].set_ylabel('Average Precision (AP)')
axes[0].set_title('Average Precision Comparison')
axes[0].legend()

# Plot AR
axes[1].bar(range(len(ar_values_model1)), ar_values_model1, width=0.4, align='center', label='MaskRCNN', color='blue', alpha=0.6)
axes[1].bar([x + 0.4 for x in range(len(ar_values_model2))], ar_values_model2, width=0.4, align='center', label='YOLO v8', color='red', alpha=0.6)
axes[1].set_xticks(range(len(ar_values_model1)))
axes[1].set_xticklabels([f'IoU={iou}, Area={area}' for iou, area in zip(iou_thresholds, areas)], rotation=45)
axes[1].set_ylabel('Average Recall (AR)')
axes[1].set_title('Average Recall Comparison')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Line Plot

import matplotlib.pyplot as plt

# First table data
data1 = [0.419, 0.498, 0.495, 0.000, 0.004, 0.419, 0.445, 0.448, 0.455, 0.000, 0.000, 0.460]
labels1 = ['AP@0.5:0.95', 'AP@0.5', 'AP@0.75', 'AP@0.5:0.95 (small)', 'AP@0.5:0.95 (medium)', 'AP@0.5:0.95 (large)',
           'AR@1', 'AR@10', 'AR@100', 'AR@100 (small)', 'AR@100 (medium)', 'AR@100 (large)']

# Second table data
data2 = [0.367, 0.522, 0.398, 0.179, 0.404, 0.521, 0.315, 0.531, 0.586, 0.366, 0.650, 0.767]
labels2 = ['AP@0.5:0.95', 'AP@0.5', 'AP@0.75', 'AP@0.5:0.95 (small)', 'AP@0.5:0.95 (medium)', 'AP@0.5:0.95 (large)',
           'AR@1', 'AR@10', 'AR@100', 'AR@100 (small)', 'AR@100 (medium)', 'AR@100 (large)']

# Set up the x-axis
x = range(len(labels1))

# Line plot
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(x, data1, marker='o', label='MaskRCNN')
ax.plot(x, data2, marker='o', label='YOLO v8')

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Comparison of Model Performance')
ax.set_xticks(x)
ax.set_xticklabels(labels1, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
# radar chart


import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['AP@0.5:0.95', 'AP@0.5', 'AP@0.75', 'AP@0.5:0.95 (small)', 'AP@0.5:0.95 (medium)', 'AP@0.5:0.95 (large)', 'AR@1', 'AR@10', 'AR@100', 'AR@100 (small)', 'AR@100 (medium)', 'AR@100 (large)']
data1 = np.array([0.419, 0.498, 0.495, 0.000, 0.004, 0.419, 0.445, 0.448, 0.455, 0.000, 0.000, 0.460])
data2 = np.array([0.367, 0.522, 0.398, 0.179, 0.404, 0.521, 0.315, 0.531, 0.586, 0.366, 0.650, 0.767])

# Angle for each metric
angles = [n / float(len(labels)) * 2 * np.pi for n in range(len(labels))]
angles += angles[:1]  # Duplicate the first angle for a closed polygon

# Draw the radar chart
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': 'polar'})
ax.set_theta_offset(np.pi / 2)  # Rotate the chart by 90 degrees
ax.set_ylim(0, 1)  # Set the radial limit

# Plot the data
ax.plot(angles, np.append(data1, data1[0]), 'o-', label='MaskRCNN')
ax.fill(angles, np.append(data1, data1[0]), alpha=0.25)
ax.plot(angles, np.append(data2, data2[0]), 'o-', label='YOLO v8')
ax.fill(angles, np.append(data2, data2[0]), alpha=0.25)

# Add labels and legend
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %%
# grouped bar
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['AP@0.5:0.95', 'AP@0.5', 'AP@0.75', 'AP@0.5:0.95 (small)', 'AP@0.5:0.95 (medium)', 'AP@0.5:0.95 (large)']
data1 = [0.419, 0.498, 0.495, 0.000, 0.004, 0.419]
data2 = [0.367, 0.522, 0.398, 0.179, 0.404, 0.521]

x = np.arange(len(labels))
width = 0.35

# Grouped bar chart
fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, data1, width, label='MaskRCNN')
rects2 = ax.bar(x + width/2, data2, width, label='YOLO v8')

# Labels and legend
ax.set_xlabel('Metrics')
ax.set_ylabel('Value')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
# AP Line plot

# claude

import matplotlib.pyplot as plt

# First table data
data1 = [0.419, 0.498, 0.495, 0.000, 0.004, 0.419]
labels1 = ['AP@0.5:0.95', 'AP@0.5', 'AP@0.75', 'AP@0.5:0.95 (small)', 'AP@0.5:0.95 (medium)', 'AP@0.5:0.95 (large)']

# Second table data
data2 = [0.367, 0.522, 0.398, 0.179, 0.404, 0.521]
labels2 = ['AP@0.5:0.95', 'AP@0.5', 'AP@0.75', 'AP@0.5:0.95 (small)', 'AP@0.5:0.95 (medium)', 'AP@0.5:0.95 (large)']

# Set up the x-axis
x = range(len(labels1))

# Line plot
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(x, data1, marker='o', label='MaskRCNN')
ax.plot(x, data2, marker='o', label='YOLO v8')

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Comparison of Model Performance')
ax.set_xticks(x)
ax.set_xticklabels(labels1, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
# AR line plot
# AP Line plot

# claude

import matplotlib.pyplot as plt

# First table data
data1 = [ 0.445, 0.448, 0.455, 0.000, 0.000, 0.460]
labels1 = ['AR@1', 'AR@10', 'AR@100', 'AR@100 (small)', 'AR@100 (medium)', 'AR@100 (large)']

# Second table data
data2 = [ 0.315, 0.531, 0.586, 0.366, 0.650, 0.767]
labels2 = ['AR@1', 'AR@10', 'AR@100', 'AR@100 (small)', 'AR@100 (medium)', 'AR@100 (large)']

# Set up the x-axis
x = range(len(labels1))

# Line plot
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(x, data1, marker='o', label='MaskRCNN')
ax.plot(x, data2, marker='o', label='YOLO v8')

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Comparison of Model Performance')
ax.set_xticks(x)
ax.set_xticklabels(labels1, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()
